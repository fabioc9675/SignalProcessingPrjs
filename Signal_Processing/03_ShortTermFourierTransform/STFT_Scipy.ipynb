# %% [markdown]
# # Short Term fourier Transform SCIPY
#
# Implementation of the STFT
#
# - Info Link [STFT](https://docs.scipy.org/doc/scipy/reference/generated/scipy.signal.spectrogram.html)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal

from scipy.fft import fft, ifft

# plt.style.use('ggplot')

# %% [markdown]
# ### Definicion de la señal de prueba

# %% [markdown]
# ## Creacion de una nueva señal chirp

# %%
# composicion de nueva señal chirp
f1_ = 1 # Frecuencia inicial del chirp
f2_ = 50 # Frecuencia final del chirp

Fs = 100 # Frecuencia de muestreo

t = np.arange(0,10.24,1/Fs) # vector de tiempos
N_ = len(t)
print("N = ", N_)

x_ = signal.chirp(t, f1_, t[-1], f2_) # Señal sin ventana
x_w = x_*signal.get_window('hamming',len(x_)) # Señal con ventana

# grafico del chirp
plt.plot(t, x_)
# Out:
# N =  1024

# %% [markdown]
# # Uso del spectrogram con scipy
#
# Uso del Spectrogram

# %%
f_, t_, Sxx = signal.spectrogram(x_, Fs, window='hamming', nperseg=100, noverlap=99, nfft=512, detrend='constant', return_onesided=True, scaling='density', axis=- 1, mode='psd')

plt.pcolormesh(t_, f_, Sxx)
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
plt.colorbar()

print(t_.shape)
print(f_.shape)
# Out:
# (925,)
# (257,)
