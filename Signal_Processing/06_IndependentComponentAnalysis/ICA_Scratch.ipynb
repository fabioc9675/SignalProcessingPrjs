# %% [markdown]
# # Independent Component Analysis for Python SCRATCH
#
# Implementation of ICA algorithm to understand the behavior of the method
#
# - This can be add throug sklearn library for python
#
# - Link [ICA_scratch](https://towardsdatascience.com/independent-component-analysis-ica-in-python-a0ef0db0955e)

# %%
import numpy as np
np.random.seed(0)
from scipy import signal
from scipy.io import wavfile
from matplotlib import pyplot as plt

import timeit # to measure the performance of the execution
# import seaborn as sns
# sns.set(rc = {'figure.figsize':(11.7,8.27)})
# %matplotlib inline

# %% [markdown]
# Se definen las matrices $g$ y $g'$

# %%
def g(x):
    return np.tanh(x)

def g_der(x):
    return 1 - g(x) * g(x)

# %% [markdown]
# Se crea la funcion para centrar la señal al substraer el mean

# %%
def center(X):
    X = np.array(X)
    mean = X.mean(axis=1, keepdims=True)

    return X - mean

# %% [markdown]
# ## Funcion Whitening
#
# se implementará la funcion h¡whitening para la construccion de la matrix de de-mixing

# %%
def whitening(X):
    cov = np.cov(X)
    d,E = np.linalg.eigh(cov)
    D = np.diag(d)
    D_inv = np.sqrt(np.linalg.inv(D))

    X_whiten = np.dot(E, np.dot(D_inv, np.dot(E.T, X)))

    return X_whiten

# %% [markdown]
# # Actualizacion de matriz W
#
# Implementacion de la funcion para la actualizacion de la matriz W

# %%
def calculate_new_w(w, X):
    w_new = (X * g(np.dot(w.T, X))).mean(axis=1) - g_der(np.dot(w.T,X)).mean() * w
    w_new /= np.sqrt((w_new ** 2).sum())

    return w_new

# %% [markdown]
# ## Metodo principal
#
# ejecucion del algoritmo y ejemplo

# %%
def ica(X, iterations, tolerance = 1e-5):
    X = center(X)  # eliminacion del nivel DC
    X = whitening(X)  # Limpieza de la senal, eliminar covarianza
    components_nr = X.shape[0]

    W = np.zeros((components_nr, components_nr), dtype=X.dtype)

    for i in range (components_nr):
        w = np.random.rand(components_nr)
        for j in range(iterations):
            w_new = calculate_new_w(w, X)

            if i >= 1:
                w_new -= np.dot(np.dot(w_new, W[:i].T), W[:i])
            
            distance = np.abs(np.abs((w * w_new).sum()) - 1)
            w = w_new

            if distance < tolerance:
                break
        
        W[i,:] = w
    
    S = np.dot(W, X)

    return S

# %% [markdown]
# Se define funcion para plotear y comparar las señales originales, las mezcladas y las predicciones

# %%
def plot_mixture_sources_predictions(X, original_sources, S):
    #fig = plt.subplot(3,1,1)
    plt.subplot(3,1,1)
    for x in X:
        plt.plot(x)
    plt.title("mixtures")

    plt.subplot(3,1,2)
    for s in original_sources:
        plt.plot(s)
    plt.title("real sources")

    plt.subplot(3,1,3)
    for s in S:
        plt.plot(s)
    plt.title("predicted sources")

    # fig.tight_layout()
    # plt.show()

# %% [markdown]
# ## Mezcla de señales
#
# mezcla artificial de señales

# %%
def mix_sources(mixtures, apply_noise=False):
    for i in range(len(mixtures)):
        max_val = np.max(mixtures[i])

        if max_val > 1 or np.min(mixtures[i]) < 1:
            mixtures[i] = mixtures[i] / (max_val / 2) - 0.5
    
    X =  np.c_[[mix for mix in mixtures]]

    if apply_noise:
        X += 0.02 * np.random.normal(size=X.shape)
    
    return X

# %% [markdown]
# Creacion de las tres señales

# %%
n_samples = 2000
time = np.linspace(0, 8, n_samples)

s1 = np.sin(2 * time)  # sinusoidal
s2 = np.sign(np.sin(3 * time))  # square signal
s3 = signal.sawtooth(2 * np.pi * time)  # saw tooth signal
s4 = np.sin(5 * time)  # saw tooth signal

# %% [markdown]
# ## Implementacion del ejemplo
#
# se computa el producto punto entre la matrix A y las señales para obtener la combinacion de las tres, luego se usa ICA para separar la mezcla

# %%
S = np.c_[s1, s2, s3, s4]
S += 0.2 * np.random.normal(size=S.shape)
S /= S.std(axis=0)
A = A = np.array(([[1, 1, 1, 1], [0.5, 2, 1.0, 2], [1.5, 1.0, 2.0, 1.5], [2, 1, 3, 1]]))
X = np.dot(S, A.T)
X = X.T
S_ = ica(X, iterations = 1000)

plot_mixture_sources_predictions(X, S.T, S_)

# %%
# performance time

print('CPU (s):')
cpu_time = timeit.timeit('ica(X, iterations = 1000)', number=10, setup="from __main__ import ica, X")
print(cpu_time/10)
# Out:
# CPU (s):
# 1.04552208899986

# %% [markdown]
# ## Uso de ICA con sklearn
#
# implementacion de sklearn para el algoritmo ICA

# %%
from sklearn.decomposition import FastICA

np.random.seed(0)
n_samples = 2000

time = np.linspace(0,8, n_samples)

s1 = np.sin(2 * time)  # sinusoidal
s2 = np.sign(np.sin(3 * time))  # square signal
s3 = signal.sawtooth(2 * np.pi * time)  # saw tooth signal
s4 = np.sin(5 * time)  # saw tooth signal

S = np.c_[s1, s2, s3, s4]
S += 0.2 * np.random.normal(size=S.shape)
S /= S.std(axis=0)
A = A = np.array(([[1, 1, 1, 1], [0.5, 2, 1.0, 2], [1.5, 1.0, 2.0, 1.5], [2, 1, 3, 1]]))
X = np.dot(S, A.T)

ica = FastICA(n_components=4)
S_ = ica.fit_transform(X)

# %% [markdown]
# Grafico de resultados

# %%
fig = plt.figure()

models = [X, S, S_]

names = ['mixture', 'real sources', ' predicted sources']
colors = ['red', 'blue', 'orange']

for i, (name, model) in enumerate(zip(names, models)):
    plt.subplot(4,1,i+1)
    plt.title(name)
    for sig, color in zip (model.T, colors):
        plt.plot(sig, color=color)

# %%
# performance time

print('CPU (s):')
cpu_time = timeit.timeit('ica.fit_transform(X)', number=10, setup="from __main__ import ica, X")
print(cpu_time/10)
# Out:
# CPU (s):
# 0.0036360807993332856

# %%
from scipy.stats import kurtosis

kurtosis_values = kurtosis(S.T, axis=1, fisher=True)
print(kurtosis_values)
# Out:
# [-1.17686315 -1.84670967 -0.9745795  -1.30662998]

# %%
plt.plot(kurtosis_values, 'o')

# %%
from sklearn.metrics import mutual_info_score

S_ = S.T

def compute_mutual_information(x, y, bins=30):
    c_xy = np.histogram2d(x, y, bins)[0]
    mi = mutual_info_score(None, None, contingency=c_xy)
    return mi

n_components = S_.shape[0]
mi_matrix = np.zeros((n_components, n_components))

for i in range(n_components):
    for j in range(n_components):
        if i != j:
            mi_matrix[i,j] = compute_mutual_information(S_[i], S_[j])

print(mi_matrix)
# Out:
# [[0.         0.15475158 0.29650634 0.20725189]
#  [0.15475158 0.         0.14620206 0.15685912]
#  [0.29650634 0.14620206 0.         0.21346047]
#  [0.20725189 0.15685912 0.21346047 0.        ]]
